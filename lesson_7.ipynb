# %%
import numpy as np
import matplotlib.pyplot as plt
from utils import plot_matrix

# %%
A = np.array([[3, 7], [5, 2]])
print(A)
# Out:
# [[3 7]
#  [5 2]]

# %%
U, D, V = np.linalg.svd(A)

# %%
sigma = np.zeros((U.shape[1], V.shape[0]))  # Matriz de ceros con el tamaño correcto
np.fill_diagonal(sigma, D)
U @ sigma @ V
# Out:
# array([[3., 7.],
#        [5., 2.]])

# %%
plot_matrix(np.eye(2))
plot_matrix(V)
plt.show()

plot_matrix(np.eye(2))
plot_matrix(sigma)
plt.show()

plot_matrix(np.eye(2))
plot_matrix(U)
plt.show()

plot_matrix(np.eye(2))
plot_matrix(A)
plt.show()
